# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
from descartes.patch import PolygonPatch
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, box

pd.set_option('display.max_columns', None)

# %%
parcels = gpd.read_file('data/parcels/geo_export_c30990f3-ca5c-43ef-ab97-46ff1d4fc38b.shp')

# %%
len(parcels)
# Out:
# 384675

# %%
def get_nearest(p, k=5):
    if hasattr(p, 'total_bounds'):
        bounds = p.total_bounds
    elif hasattr(p, 'bounds'):
        bounds = p.bounds
    else:
        bounds = p
    hits = list(parcels.sindex.nearest(bounds, k))
    return parcels.geometry.iloc[hits]

p = parcels.geometry.ix[0]
get_nearest(p, 100).plot()

# %%
len(parcels.parcelno), len(parcels.parcelno[~parcels.parcelno.isnull()]), len(parcels.parcelno.unique())
# Out:
# (384675, 384601, 384403)

# %%
len(parcels.objectid), len(parcels.objectid[~parcels.objectid.isnull()]), len(parcels.objectid.unique())
# Out:
# (384675, 384675, 384675)

# %%
group = parcels[parcels.parcelno == '22002318.001']
group.geometry.plot()

# %%
get_nearest(group.geometry, 100).plot()

# %%
demolition = pd.read_csv('data/detroit-demolition-permits.tsv', sep='\t')
demolition = demolition.join(demolition.site_location.str.extract(r'\((?P<Lat>.+)?,\s*(?P<Lon>.+)?\)', expand=True).astype(float))
geometry = demolition.apply(lambda row: Point(row.Lon, row.Lat), axis=1)
demolition = gpd.GeoDataFrame(demolition, geometry=geometry, crs={'init': 'epsg:4326'})

# %%
demolition[~demolition.PARCEL_NO.str.contains(r'^\d+ +\d+(?:\.(?:\d+L?)?|-\d+)$')]
# Out:
#           PERMIT_NO PERMIT_APPLIED PERMIT_ISSUED PERMIT_EXPIRES  \
# 6575  BLD2011-01231        2/16/11       2/16/11        8/16/11
# 6576  BLD2011-01231        2/16/11       2/16/11        8/16/11
# 6969  BLD2010-01114        7/13/10       7/13/10        1/13/11
# 7116  BLD2010-00154        5/25/10       5/25/10       11/25/10
#
#              SITE_ADDRESS BETWEEN1 PARCEL_NO LOT_NUMBER SUBDIVISION CASE_TYPE  \
# 6575  17200 SOUTH HAMPTON      NaN         0        NaN         NaN       BLD
# 6576  17200 SOUTH HAMPTON      NaN         0        NaN         NaN       BLD
# 6969        2920 E PALMER      NaN         0        NaN         NaN       BLD
# 7116         8210 CAMERON      NaN         0        NaN         NaN       BLD
#
#      CASE_DESCRIPTION LEGAL_USE ESTIMATED_COST  PARCEL_SIZE  \
# 6575  Building Permit    SCHOOL            NaN          NaN
# 6576  Building Permit    SCHOOL            NaN          NaN
# 6969  Building Permit    SCHOOL            NaN          NaN
# 7116  Building Permit    SCHOOL            NaN          NaN
#
#       PARCEL_CLUSTER_SECTOR  STORIES  PARCEL_FLOOR_AREA  PARCEL_GROUND_AREA  \
# 6575                    NaN     15.0                NaN                 NaN
# 6576                    NaN     15.0                NaN                 NaN
# 6969                    NaN      1.0                NaN                 NaN
# 7116                    NaN      2.0                NaN                 NaN
#
#      PRC_AKA_ADDRESS BLD_PERMIT_TYPE PERMIT_DESCRIPTION  \
# 6575             NaN            DISM          Dismantle
# 6576             NaN            DISM          Dismantle
# 6969             NaN            DISM          Dismantle
# 7116             NaN            DISM          Dismantle
#
#               BLD_PERMIT_DESC BLD_TYPE_USE      RESIDENTIAL DESCRIPTION  \
# 6575   WRECK & REMOVE DEBRIS.           41  NON-RESIDENTIAL      School
# 6576   WRECK & REMOVE DEBRIS.           41  NON-RESIDENTIAL      School
# 6969  WRECK AND REMOVE DEBRIS           41  NON-RESIDENTIAL      School
# 7116  WRECK AND REMOVE DEBRIS           41  NON-RESIDENTIAL      School
#
#      BLD_TYPE_CONST_COD BLD_ZONING_DIST BLD_USE_GROUP BLD_BASEMENT FEE_TYPE  \
# 6575                 1B              B1             E            Y     WPMT
# 6576                 1B              B1             E            Y     WPMT
# 6969                 1B             NaN             E          NaN     WPM2
# 7116                 1B             NaN             E            N     WPMT
#
#          CSM_CASENO CSF_CREATED_BY  SEQ_NO PCF_AMT_PD PCF_AMT_DUE PCF_UPDATED  \
# 6575  BLD2011-01231           M-JD       1  $5,036.20   $5,036.20     2/16/11
# 6576  BLD2011-01231           M-JD       1  $5,036.20   $5,036.20     2/16/11
# 6969  BLD2010-01114            GRE       1  $2,288.55   $2,288.55     7/13/10
# 7116  BLD2010-00154            GRE       1  $1,425.40   $1,425.40     5/25/10
#
#              OWNER_LAST_NAME OWNER_FIRST_NAME     OWNER_ADDRESS1  \
# 6575  DETROIT PUBLIC SCHOOLS              NaN  3031 W GRAND BLVD
# 6576  DETROIT PUBLIC SCHOOLS              NaN  3031 W GRAND BLVD
# 6969   DETROIT PUBLIC SCHOOL              NaN      2920 E PALMER
# 7116                    BEAL          STEWART       221 FELCH ST
#
#      OWNER_ADDRESS2 OWNER_CITY OWNER_STATE OWNER_ZIP  \
# 6575            NaN    DETROIT          MI     48202
# 6576            NaN    DETROIT          MI     48202
# 6969            NaN    DETROIT          MI     48211
# 7116            NaN  ANN ARBOR          MI     48103
#
#                CONTRACTOR_LAST_NAME CONTRACTOR_FIRST_NAME CONTRACTOR_ADDRESS1  \
# 6575  ADAMO DEMOLITION COMPANY 2011                   NaN    300 E SEVEN MILE
# 6576  ADAMO DEMOLITION COMPANY 2011                   NaN    300 E SEVEN MILE
# 6969       FARROW GROUP INC    2010                   NaN    601 BEAUFAIT AVE
# 7116              BEAL INCORPORATED                   NaN    277 GRATIOT #510
#
#      CONTRACTOR_ADDRESS2 CONTRACTOR_CITY CONTRACTOR_STATE  CONTRACTOR_ZIP  \
# 6575                 NaN         DETROIT               MI         48203.0
# 6576                 NaN         DETROIT               MI         48203.0
# 6969                 NaN         DETROIT               MI         48207.0
# 7116                 NaN         DETROIT               MI         48226.0
#
#      CONDITION_FOR_APPROVAL  \
# 6575                    NaN
# 6576                    NaN
# 6969                    NaN
# 7116                    NaN
#
#                                           site_location  \
# 6575  17200 SOUTH HAMPTON\nDETROIT, MI\n(42.33168113...
# 6576  17200 SOUTH HAMPTON\nDETROIT, MI\n(42.33168113...
# 6969  2920 E PALMER\nDETROIT, MI\n(42.37208105400003...
# 7116  8210 CAMERON\nDETROIT, MI\n(42.37923932800004,...
#
#                                          owner_location  \
# 6575  3031 W GRAND BLVD\nDETROIT, MI 48202\n(42.3693...
# 6576  3031 W GRAND BLVD\nDETROIT, MI 48202\n(42.3693...
# 6969  2920 E PALMER\nDETROIT, MI 48211\n(42.37208105...
# 7116  221 FELCH ST\nANN ARBOR, MI 48103\n(42.2863418...
#
#                                     contractor_location geom        Lat  \
# 6575  300 E SEVEN\nDETROIT, MI 48203\n(42.3343817120...  NaN  42.331681
# 6576  300 E SEVEN\nDETROIT, MI 48203\n(42.3343817120...  NaN  42.331681
# 6969  601 BEAUFAIT AVE\nDETROIT, MI 48207\n(42.34586...  NaN  42.372081
# 7116  277 GRATIOT\nDETROIT, MI 48226\n(42.3351206730...  NaN  42.379239
#
#             Lon                                      geometry
# 6575 -83.047996  POINT (-83.04799603699996 42.33168113800008)
# 6576 -83.047996  POINT (-83.04799603699996 42.33168113800008)
# 6969 -83.040939  POINT (-83.04093859199997 42.37208105400003)
# 7116 -83.065327  POINT (-83.06532742299999 42.37923932800004)

# %%
parcel_counts = parcels.parcelno.value_counts()
fig, ax = plt.subplots(figsize=(10, 10))
ax.set_aspect('equal')
parcels[parcels.parcelno.isin(parcel_counts[parcel_counts > 1].index)].plot(column='parcelno', ax=ax)

# %%
demolition_with_coordinates = demolition[~demolition.Lat.isnull() & ~demolition.Lon.isnull()]

center = demolition_with_coordinates.sample(1).iloc[0].geometry
hits = list(demolition_with_coordinates.sindex.nearest(center.bounds, 50))
demolition_sample = demolition_with_coordinates.iloc[hits]
parcels_sample = parcels[parcels.within(box(*demolition_sample.total_bounds))]

fig, ax = plt.subplots(figsize=(10, 10))

lat_min, lat_max = demolition_sample.Lat.min(), demolition_sample.Lat.max()
lon_min, lon_max = demolition_sample.Lon.min(), demolition_sample.Lon.max()

m = Basemap(
    epsg=4326,
    llcrnrlat=lat_min,
    urcrnrlat=lat_max,
    llcrnrlon=lon_min,
    urcrnrlon=lon_max,
    ax=ax,
)

m.arcgisimage(service='World_Topo_Map', xpixels=800, verbose=True)

ax.add_collection(PatchCollection(parcels_sample.geometry.map(PolygonPatch)))

m.scatter(
    demolition_sample.geometry.map(lambda p: p.x),
    demolition_sample.geometry.map(lambda p: p.y),
    color='k',
)

ax.add_collection(PatchCollection(
    parcels_sample[parcels_sample.parcelno == '01006556.'].geometry.map(PolygonPatch), color='g'))
m.scatter(
    demolition_sample.geometry.map(lambda p: p.x)[:1],
    demolition_sample.geometry.map(lambda p: p.y)[:1],
    color='r',
)
# Out:
# http://server.arcgisonline.com/ArcGIS/rest/services/World_Topo_Map/MapServer/export?bbox=-83.20351,42.34848099000004,-83.17883768699994,42.36744985300004&bboxSR=4326&imageSR=4326&size=800,615&dpi=96&format=png32&f=image
# /workspace/conda/envs/ds/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3310: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /workspace/conda/envs/ds/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3319: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# /workspace/conda/envs/ds/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3236: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /workspace/conda/envs/ds/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3245: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)

# %%
len(demolition), len(parcels)
# Out:
# (7133, 384675)

# %%
def demolition_row_to_parcel(demolition_row):
    print(demolition_row.PARCEL_NO)
    p = demolition_row.geometry
    neighbors = parcels.iloc[list(parcels.sindex.nearest(p.bounds, 10))]
    neighbors.plot(column='parcelno', legend=True)
    plt.scatter([p.x], [p.y], c='k')
    plt.show()
    distances = neighbors.distance(p).sort_values()
    return distances.to_frame('Distance').join(neighbors.loc[distances.index].parcelno)

demolition_row_to_parcel(demolition_with_coordinates.sample().iloc[0])
# Out:
# 15 10009.002L
#         Distance       parcelno
# 110157  0.000033  15010009.002L
# 110158  0.000048      15010010.
# 110156  0.000054   15010009.001
# 110159  0.000138      15010011.
# 110587  0.000166      15010471.
# 110586  0.000170      15010470.
# 101985  0.000176   15000265.002
# 110585  0.000208      15010469.
# 110160  0.000224      15010012.
# 110155  0.000283      15010008.

# %%
parcels = parcels[~parcels.parcelno.isnull() & ~parcels.geometry.isnull()]
parcels = parcels.join(parcels.parcelno.str.extract(r'^(?P<Main>\d+)(?:[-\.](?P<Tail>.+?))?\.?$', expand=True).fillna(''))
parcels = parcels.join(parcels.apply(lambda row: '{Main}.{Tail}'.format(**row), axis=1).to_frame('ParcelNo'))
parcels = parcels.drop('parcelno', axis=1)

# %%
demolition = demolition.join(demolition.PARCEL_NO.str.extract(r'^(?P<Head>\d+) +(?P<Body>\d+)[-\.](?P<Tail>.+?)?$', expand=True).fillna(''))
demolition = demolition.join(demolition.apply(lambda row: '{Head:>02}{Body:>06}'.format(**row), axis=1).to_frame('Main'))
demolition = demolition.join(demolition.apply(lambda row: '{Head:>02}{Body:>06}.{Tail}'.format(**row), axis=1).to_frame('ParcelNo'))
demolition = demolition.drop('PARCEL_NO', axis=1)

# %%
same_main = pd.merge(demolition[['ParcelNo', 'SITE_ADDRESS', 'Main', 'Tail']],
             parcels[['Main', 'Tail', 'ParcelNo', 'propaddr']],
             on='Main', how='inner').fillna('')
same_tail = same_main[same_main.Tail_x == same_main.Tail_y]
same_main_different_tail = same_main[~same_main.Main.isin(same_tail.Main)].sort_values('Main')
same_main_different_tail[['Main', 'Tail_x', 'Tail_y', 'ParcelNo_x', 'ParcelNo_y', 'SITE_ADDRESS', 'propaddr']]
# Out:
#           Main Tail_x Tail_y     ParcelNo_x     ParcelNo_y  \
# 4377  01004087     97     96    01004087.97    01004087.96
# 4376  01004087     97     96    01004087.97    01004087.96
# 8625  01007676             7      01007676.     01007676.7
# 8860  04002764             5      04002764.     04002764.5
# 1218  06006164             8      06006164.     06006164.8
# 8817  08003913             0      08003913.     08003913.0
# 8816  08003913             0      08003913.     08003913.0
# 1090  10005318             9      10005318.     10005318.9
# 8531  12004504            16      12004504.    12004504.16
# 7716  12008654   002L         12008654.002L      12008654.
# 3899  13000001           002      13000001.   13000001.002
# 3900  13000001          003L      13000001.  13000001.003L
# 3898  13000001           001      13000001.   13000001.001
# 7017  13005455             7      13005455.     13005455.7
# 6832  13006809          003L      13006809.  13006809.003L
# 6833  13006809           001      13006809.   13006809.001
# 6834  13006809           002      13006809.   13006809.002
# 6835  13006809          003L      13006809.  13006809.003L
# 6837  13006809           002      13006809.   13006809.002
# 6838  13006809          003L      13006809.  13006809.003L
# 6841  13006809          003L      13006809.  13006809.003L
# 6839  13006809           001      13006809.   13006809.001
# 6831  13006809           002      13006809.   13006809.002
# 6840  13006809           002      13006809.   13006809.002
# 6836  13006809           001      13006809.   13006809.001
# 6830  13006809           001      13006809.   13006809.001
# 6825  13006809           002      13006809.   13006809.002
# 6828  13006809           002      13006809.   13006809.002
# 6827  13006809           001      13006809.   13006809.001
# 6826  13006809          003L      13006809.  13006809.003L
# ...        ...    ...    ...            ...            ...
# 7637  22057501    002    016   22057501.002   22057501.016
# 7638  22057501    002    017   22057501.002   22057501.017
# 7639  22057501    002    018   22057501.002   22057501.018
# 7640  22057501    002    019   22057501.002   22057501.019
# 7628  22057501    002    007   22057501.002   22057501.007
# 7642  22057501    002    021   22057501.002   22057501.021
# 7643  22057501    002    022   22057501.002   22057501.022
# 7663  22057501    002    042   22057501.002   22057501.042
# 7645  22057501    002    024   22057501.002   22057501.024
# 7644  22057501    002    023   22057501.002   22057501.023
# 7647  22057501    002    026   22057501.002   22057501.026
# 7661  22057501    002    040   22057501.002   22057501.040
# 7660  22057501    002    039   22057501.002   22057501.039
# 7659  22057501    002    038   22057501.002   22057501.038
# 7658  22057501    002    037   22057501.002   22057501.037
# 7657  22057501    002    036   22057501.002   22057501.036
# 7646  22057501    002    025   22057501.002   22057501.025
# 7655  22057501    002    034   22057501.002   22057501.034
# 7656  22057501    002    035   22057501.002   22057501.035
# 7653  22057501    002    032   22057501.002   22057501.032
# 7652  22057501    002    031   22057501.002   22057501.031
# 7651  22057501    002    030   22057501.002   22057501.030
# 7650  22057501    002    029   22057501.002   22057501.029
# 7649  22057501    002    028   22057501.002   22057501.028
# 7648  22057501    002    027   22057501.002   22057501.027
# 7654  22057501    002    033   22057501.002   22057501.033
# 7641  22057501    002    020   22057501.002   22057501.020
# 2342  22110526             7      22110526.     22110526.7
# 4068  22124896             7      22124896.     22124896.7
# 4067  22124896             7      22124896.     22124896.7
#
#                            SITE_ADDRESS             propaddr
# 4377                       500 WOODWARD  500 WOODWARD AVENUE
# 4376            500 WOODWARD 19TH FLOOR  500 WOODWARD AVENUE
# 8625                       974 FERNHILL         974 FERNHILL
# 8860                  630 W BOSTON BLVD    610 W BOSTON BLVD
# 1218                     4801  ELMHURST        1584 ELMHURST
# 8817                      2335 HIGHLAND        2335 HIGHLAND
# 8816                      2335 HIGHLAND        2335 HIGHLAND
# 1090                         1481  14TH         1435 14TH ST
# 8531                     3026 W DAVISON       2900 W DAVISON
# 7716                   3606 TWENTYFIFTH         3602 24TH ST
# 3899                    100 RIVER PLACE        3100 GUOIN 1B
# 3900                    100 RIVER PLACE         3100 GUOIN 2
# 3898                    100 RIVER PLACE        3100 GUOIN 1A
# 7017                   5679 - 85 CANIFF          5685 CANIFF
# 6832  11705 - 11 MOUND RD.   BLDG.  401         5550 CHARLES
# 6833      5860 - 78 CHARLES   BLDG  204         5550 CHARLES
# 6834      5860 - 78 CHARLES   BLDG  204         5550 CHARLES
# 6835      5860 - 78 CHARLES   BLDG  204         5550 CHARLES
# 6837          5824- 5848 CHARLES STREET         5550 CHARLES
# 6838          5824- 5848 CHARLES STREET         5550 CHARLES
# 6841   11801 - 07 MOUND RD.   BLDG. 212         5550 CHARLES
# 6839   11801 - 07 MOUND RD.   BLDG. 212         5550 CHARLES
# 6831  11705 - 11 MOUND RD.   BLDG.  401         5550 CHARLES
# 6840   11801 - 07 MOUND RD.   BLDG. 212         5550 CHARLES
# 6836          5824- 5848 CHARLES STREET         5550 CHARLES
# 6830  11705 - 11 MOUND RD.   BLDG.  401         5550 CHARLES
# 6825   11809 - 23 MOUND RD.   BLDG. 206         5550 CHARLES
# 6828   11801 - 07 MOUND RD.   BLDG. 212         5550 CHARLES
# 6827   11801 - 07 MOUND RD.   BLDG. 212         5550 CHARLES
# 6826   11809 - 23 MOUND RD.   BLDG. 206         5550 CHARLES
# ...                                 ...                  ...
# 7637                    19960 MANSFIELD      20514 MANSFIELD
# 7638                    19960 MANSFIELD      20522 MANSFIELD
# 7639                    19960 MANSFIELD      20530 MANSFIELD
# 7640                    19960 MANSFIELD      20540 MANSFIELD
# 7628                    19960 MANSFIELD      20244 MANSFIELD
# 7642                    19960 MANSFIELD      20574 MANSFIELD
# 7643                    19960 MANSFIELD      20575 MANSFIELD
# 7663                    19960 MANSFIELD      20093 MANSFIELD
# 7645                    19960 MANSFIELD      20545 MANSFIELD
# 7644                    19960 MANSFIELD      20561 MANSFIELD
# 7647                    19960 MANSFIELD      20525 MANSFIELD
# 7661                    19960 MANSFIELD      20111 MANSFIELD
# 7660                    19960 MANSFIELD      20203 MANSFIELD
# 7659                    19960 MANSFIELD      20213 MANSFIELD
# 7658                    19960 MANSFIELD      20223 MANSFIELD
# 7657                    19960 MANSFIELD      20241 MANSFIELD
# 7646                    19960 MANSFIELD      20535 MANSFIELD
# 7655                    19960 MANSFIELD      20261 MANSFIELD
# 7656                    19960 MANSFIELD      20251 MANSFIELD
# 7653                    19960 MANSFIELD      20279 MANSFIELD
# 7652                    19960 MANSFIELD      20291 MANSFIELD
# 7651                    19960 MANSFIELD      20303 MANSFIELD
# 7650                    19960 MANSFIELD      20315 MANSFIELD
# 7649                    19960 MANSFIELD      20503 MANSFIELD
# 7648                    19960 MANSFIELD      20515 MANSFIELD
# 7654                    19960 MANSFIELD      20269 MANSFIELD
# 7641                    19960 MANSFIELD      20560 MANSFIELD
# 2342                      14842 BENTLER        14842 BENTLER
# 4068                11071 W OUTER DRIVE  11011 W OUTER DRIVE
# 4067                11071 W OUTER DRIVE  11011 W OUTER DRIVE
#
# [118 rows x 7 columns]

# %%
from IPython.display import display

def inspect(main):
    p = parcels[parcels.Main == main]
    g = demolition[demolition.Main == main]
    if g.Lat.isnull().any():
        return
    display(p[['propaddr', 'ParcelNo']])
    display(g[['SITE_ADDRESS', 'ParcelNo']])
    fig, ax = plt.subplots()
    get_nearest(g, 10).plot(ax=ax, color='white')
    p.plot(ax=ax)
    g.plot(color='r', ax=ax)
    plt.show()

mains = list(same_main_different_tail.Main.unique())
# The code below crashes the kernel.
#for main in mains:
#    inspect(main)

# %%
demolition.BLD_PERMIT_TYPE.unique()
# Out:
# array(['Dismantle', 'DISM'], dtype=object)

# %%
parcels.head(1)
# Out:
#      aka          av  cibbldgno  cibflarea  cibocc  cibyrbuilt  date_saled  \
# 74  None  55094700.0        3.0  5102782.0    88.0      1977.0  1996-10-01
#
#     depth  district    ecf  frontage  \
# 74    0.0       4.0  4Z100       0.0
#
#                                              geometry  homestead  isimproved  \
# 74  POLYGON ((-83.04165895478116 42.32955486866187...        0.0         1.0
#
#    landmap   landvalue                                              legal  \
# 74     356  59531900.0  S JEFFERSON E PT LOTS 1 THRU 10 18 THRU 27 34 ...
#
#      nez  objectid prevpclass prevtstatu         propaddr propclass propdir  \
# 74  None  181818.0        202    TAXABLE  400 E JEFFERSON       204       E
#
#     propno propstatus    propstr propzip related  resbldgno  resflarea  \
# 74   400.0     Active  JEFFERSON   48226    None        0.0        0.0
#
#     resocc resstyle  resyrbuilt   rp   saleprice         sev     shape_star  \
# 74     0.0     None         0.0  0.0  73000000.0  55094700.0  590301.475586
#
#      shape_stle specact subdivisio                       taxaddr  taxcity  \
# 74  3097.195265    None       None  200 RENAISSANCE CTR STE 1200  DETROIT
#
#                  taxpayer_1 taxpayer_2 taxstate taxstatus      taxzip  \
# 74  RIVERFRONT HOLDINGS INC       None       MI   TAXABLE  48243-1300
#
#       time_saled  totalacrea  totalsqft          tv usecode ward xstrname_1  \
# 74  00:00:00.000      13.667   595335.0  46400139.0   22320   01   RANDOLPH
#
#    xstrname_2      Main Tail   ParcelNo
# 74   BEAUBIEN  01000001       01000001.

# %%
parcels = parcels[['ParcelNo', 'propaddr', 'geometry']].rename(columns={'propaddr': 'StreetAddress'})
parcels['IsBlighted'] = parcels.ParcelNo.isin(demolition.ParcelNo)

# %%
parcels.head(1)
# Out:
#      ParcelNo    StreetAddress  \
# 74  01000001.  400 E JEFFERSON
#
#                                              geometry IsBlighted
# 74  POLYGON ((-83.04165895478116 42.32955486866187...       True

# %%
# !mkdir -p output
parcels.to_csv('output/parcels.csv', index=False)
